# %%
import os

os.makedirs("self_cooperation_rates", exist_ok=True)

# %%
import axelrod as axl
import numpy as np
from agents.aif.jax.five_state import JaxFiveStateAgent
import random

np.random.seed(42)
random.seed(42)
# Generate noise levels from 0 to 0.5 at 0.05 intervals
noise_levels = list(np.arange(0, 0.05, 0.05).round(2))
# noise_levels = list(np.arange(0, 0.55, 0.05).round(2))

strategies = [
    JaxFiveStateAgent,
]

for strategy in strategies:
    os.makedirs(f"jax_hyperparameter_tuning/{strategy().name}", exist_ok=True)

# %%
from tournament.handler import FileSystemHandler
from tournament.tournament import NoiseTournament
import itertools

gammas = [0.2, 0.8, 1.0]
alphas = [0.2, 0.8, 1.0]
lrs_B = [0.5, 1, 1.5]
update_intervals = [50, 100, 150, 200]


for gamma, alpha, lr_B, update_interval in itertools.product(gammas, alphas, lrs_B, update_intervals):
    repetitions = 5
    seed = 42
    turns = 1000
    processes = os.cpu_count() - 1
    players = []
    player = JaxFiveStateAgent(seed=0, gamma=gamma, alpha=alpha, lr_B=lr_B, update_interval=update_interval)
    player.name = f"AIF_{gamma}_{alpha}_{lr_B}_{update_interval}"
    players.append(player)
    # # 2. Instantiate the handler
    handler = FileSystemHandler(root_dir=f"jax_hyperparameter_tuning/{player.name}")

    # # 3. Instantiate the tournament with the handler's callbacks
    noise_tournament = NoiseTournament(
        players=players,
        noise_levels=noise_levels,
        repetitions=repetitions,
        seed=seed,
        callback=handler.save_results,
        skip_callback=handler.skip_run,
    )

    # # 4. Run the tournament
    noise_tournament.run(turns=turns, processes=processes)

    # print("Test tournament finished.")
    print(f"Results are saved in the '{handler.root_dir}' directory.")
# Out:
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_50/repetition_0/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_50/repetition_1/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_50/repetition_2/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_50/repetition_3/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_50/repetition_4/0.0.csv
# 0it [00:00, ?it/s]
# Results are saved in the 'jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_50' directory.
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_100/repetition_0/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_100/repetition_1/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_100/repetition_2/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_100/repetition_3/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_100/repetition_4/0.0.csv
# 0it [00:00, ?it/s]
# Results are saved in the 'jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_100' directory.
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_150/repetition_0/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_150/repetition_1/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_150/repetition_2/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_150/repetition_3/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_150/repetition_4/0.0.csv
# 0it [00:00, ?it/s]
# Results are saved in the 'jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_150' directory.
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_200/repetition_0/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_200/repetition_1/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_200/repetition_2/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_200/repetition_3/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_200/repetition_4/0.0.csv
# 0it [00:00, ?it/s]
# Results are saved in the 'jax_hyperparameter_tuning/AIF_0.2_0.2_0.5_200' directory.
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_1_50/repetition_0/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_1_50/repetition_1/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_1_50/repetition_2/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_1_50/repetition_3/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_1_50/repetition_4/0.0.csv
# 0it [00:00, ?it/s]
# Results are saved in the 'jax_hyperparameter_tuning/AIF_0.2_0.2_1_50' directory.
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_1_100/repetition_0/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_1_100/repetition_1/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_1_100/repetition_2/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_1_100/repetition_3/0.0.csv
# Skipping existing run: jax_hyperparameter_tuning/AIF_0.2_0.2_1_100/repetition_4/0.0.csv
# 0it [00:00, ?it/s]
# Results are saved in the 'jax_hyperparameter_tuning/AIF_0.2_0.2_1_100' directory.
# 100%|██████████| 5/5 [01:24<00:00, 16.90s/it]
# Results are saved in the 'jax_hyperparameter_tuning/AIF_0.2_0.2_1_150' directory.
# 100%|██████████| 5/5 [01:35<00:00, 19.03s/it]
# Results are saved in the 'jax_hyperparameter_tuning/AIF_0.2_0.2_1_200' directory.
# 100%|██████████| 5/5 [01:39<00:00, 19.85s/it]
# Results are saved in the 'jax_hyperparameter_tuning/AIF_0.2_0.2_1.5_50' directory.
# 100%|██████████| 5/5 [01:30<00:00, 18.15s/it]
# Results are saved in the 'jax_hyperparameter_tuning/AIF_0.2_0.2_1.5_100' directory.
# 100%|██████████| 5/5 [01:28<00:00, 17.66s/it]
# Results are saved in the 'jax_hyperparameter_tuning/AIF_0.2_0.2_1.5_150' directory.
#   0%|          | 0/5 [00:00<?, ?it/s]Process SpawnPoolWorker-377:
# Process SpawnPoolWorker-378:
# Process SpawnPoolWorker-371:
# Process SpawnPoolWorker-370:
# Process SpawnPoolWorker-376:
# Process SpawnPoolWorker-373:
# Process SpawnPoolWorker-375:
# Process SpawnPoolWorker-366:
# Process SpawnPoolWorker-368:
# Process SpawnPoolWorker-365:
# Process SpawnPoolWorker-364:
# Process SpawnPoolWorker-367:
# Process SpawnPoolWorker-360:
# Process SpawnPoolWorker-372:
# Process SpawnPoolWorker-359:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process SpawnPoolWorker-363:
# Process SpawnPoolWorker-361:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 385, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.13/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.13/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.13/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/src/tournament/tournament.py", line 95, in _run_single_tournament_worker
#     results = tour.play(
#         build_results=True, progress_bar=False, filename=filename
#     )
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/axelrod/tournament.py", line 152, in play
#     self._run_serial(build_results=build_results)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/axelrod/tournament.py", line 181, in _run_serial
#     results = self._play_matches(chunk, build_results=build_results)
#   File "/home/kivalm/code/AIFNIPD/src/tournament/tournament.py", line 47, in _play_matches
#     match.play()
#     ~~~~~~~~~~^^
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/axelrod/match.py", line 197, in play
#     plays = self.simultaneous_play(
#         self.players[0], self.players[1], self.noise
#     )
#   File "/home/kivalm/code/AIFNIPD/src/tournament/tournament.py", line 22, in simultaneous_play
#     s1, s2 = player.strategy(coplayer), coplayer.strategy(player)
#                                         ~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/src/agents/wrapper.py", line 53, in strategy
#     action = self.step(state)
#   File "/home/kivalm/code/AIFNIPD/src/agents/aif/jax/five_state.py", line 167, in step
#     return Action.C if action[0][0] == C else Action.D
#                        ^^^^^^^^^^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/jax/_src/array.py", line 308, in __bool__
#     return bool(self._value)
#                 ^^^^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/jax/_src/array.py", line 644, in _value
#     npy_value, did_copy = self._single_device_array_to_np_array_did_copy()
#                           ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# Process SpawnPoolWorker-369:
# KeyboardInterrupt
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 385, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.13/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.13/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.13/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/src/tournament/tournament.py", line 95, in _run_single_tournament_worker
#     results = tour.play(
#         build_results=True, progress_bar=False, filename=filename
#     )
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/axelrod/tournament.py", line 152, in play
#     self._run_serial(build_results=build_results)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/axelrod/tournament.py", line 181, in _run_serial
#     results = self._play_matches(chunk, build_results=build_results)
#   File "/home/kivalm/code/AIFNIPD/src/tournament/tournament.py", line 47, in _play_matches
#     match.play()
#     ~~~~~~~~~~^^
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/axelrod/match.py", line 197, in play
#     plays = self.simultaneous_play(
#         self.players[0], self.players[1], self.noise
#     )
#   File "/home/kivalm/code/AIFNIPD/src/tournament/tournament.py", line 22, in simultaneous_play
#     s1, s2 = player.strategy(coplayer), coplayer.strategy(player)
#              ~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/src/agents/wrapper.py", line 53, in strategy
#     action = self.step(state)
#   File "/home/kivalm/code/AIFNIPD/src/agents/aif/jax/five_state.py", line 167, in step
#     return Action.C if action[0][0] == C else Action.D
#                        ^^^^^^^^^^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/jax/_src/array.py", line 308, in __bool__
#     return bool(self._value)
#                 ^^^^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/jax/_src/array.py", line 644, in _value
#     npy_value, did_copy = self._single_device_array_to_np_array_did_copy()
#                           ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
# Process SpawnPoolWorker-358:
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/src/tournament/tournament.py", line 95, in _run_single_tournament_worker
#     results = tour.play(
#         build_results=True, progress_bar=False, filename=filename
#     )
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/axelrod/tournament.py", line 152, in play
#     self._run_serial(build_results=build_results)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/axelrod/tournament.py", line 181, in _run_serial
#     results = self._play_matches(chunk, build_results=build_results)
#   File "/home/kivalm/code/AIFNIPD/src/tournament/tournament.py", line 47, in _play_matches
#     match.play()
#     ~~~~~~~~~~^^
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/axelrod/match.py", line 197, in play
#     plays = self.simultaneous_play(
#         self.players[0], self.players[1], self.noise
#     )
#   File "/home/kivalm/code/AIFNIPD/src/tournament/tournament.py", line 22, in simultaneous_play
#     s1, s2 = player.strategy(coplayer), coplayer.strategy(player)
#                                         ~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/src/agents/wrapper.py", line 53, in strategy
#     action = self.step(state)
#   File "/home/kivalm/code/AIFNIPD/src/agents/aif/jax/five_state.py", line 167, in step
#     return Action.C if action[0][0] == C else Action.D
#                        ^^^^^^^^^^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/jax/_src/array.py", line 308, in __bool__
#     return bool(self._value)
#                 ^^^^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/jax/_src/array.py", line 644, in _value
#     npy_value, did_copy = self._single_device_array_to_np_array_did_copy()
#                           ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
# Process SpawnPoolWorker-362:
# Process SpawnPoolWorker-374:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/src/tournament/tournament.py", line 95, in _run_single_tournament_worker
#     results = tour.play(
#         build_results=True, progress_bar=False, filename=filename
#     )
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/axelrod/tournament.py", line 152, in play
#     self._run_serial(build_results=build_results)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/axelrod/tournament.py", line 181, in _run_serial
#     results = self._play_matches(chunk, build_results=build_results)
#   File "/home/kivalm/code/AIFNIPD/src/tournament/tournament.py", line 47, in _play_matches
#     match.play()
#     ~~~~~~~~~~^^
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/axelrod/match.py", line 197, in play
#     plays = self.simultaneous_play(
#         self.players[0], self.players[1], self.noise
#     )
#   File "/home/kivalm/code/AIFNIPD/src/tournament/tournament.py", line 22, in simultaneous_play
#     s1, s2 = player.strategy(coplayer), coplayer.strategy(player)
#                                         ~~~~~~~~~~~~~~~~~^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/src/agents/wrapper.py", line 53, in strategy
#     action = self.step(state)
#   File "/home/kivalm/code/AIFNIPD/src/agents/aif/jax/five_state.py", line 167, in step
#     return Action.C if action[0][0] == C else Action.D
#                        ^^^^^^^^^^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/jax/_src/array.py", line 308, in __bool__
#     return bool(self._value)
#                 ^^^^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/jax/_src/array.py", line 644, in _value
#     npy_value, did_copy = self._single_device_array_to_np_array_did_copy()
#                           ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/usr/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/src/tournament/tournament.py", line 95, in _run_single_tournament_worker
#     results = tour.play(
#         build_results=True, progress_bar=False, filename=filename
#     )
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/axelrod/tournament.py", line 152, in play
#     self._run_serial(build_results=build_results)
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/axelrod/tournament.py", line 181, in _run_serial
#     results = self._play_matches(chunk, build_results=build_results)
#   File "/home/kivalm/code/AIFNIPD/src/tournament/tournament.py", line 47, in _play_matches
#     match.play()
#     ~~~~~~~~~~^^
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/axelrod/match.py", line 197, in play
#     plays = self.simultaneous_play(
#         self.players[0], self.players[1], self.noise
#     )
#   File "/home/kivalm/code/AIFNIPD/src/tournament/tournament.py", line 22, in simultaneous_play
#     s1, s2 = player.strategy(coplayer), coplayer.strategy(player)
#              ~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/src/agents/wrapper.py", line 53, in strategy
#     action = self.step(state)
#   File "/home/kivalm/code/AIFNIPD/src/agents/aif/jax/five_state.py", line 167, in step
#     return Action.C if action[0][0] == C else Action.D
#                        ^^^^^^^^^^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/jax/_src/array.py", line 308, in __bool__
#     return bool(self._value)
#                 ^^^^^^^^^^^
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/jax/_src/profiler.py", line 364, in wrapper
#     return func(*args, **kwargs)
#   File "/home/kivalm/code/AIFNIPD/.venv/lib/python3.13/site-packages/jax/_src/array.py", line 644, in _value
#     npy_value, did_copy = self._single_device_array_to_np_array_did_copy()
#                           ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import glob

# Get all strategy directories
strategy_dirs = [d for d in Path("jax_hyperparameter_tuning").iterdir() if d.is_dir()]

strategy_dirs = list(filter(lambda x: x.name.count("AIF") != 0 or x.name.count("Q") != 0, strategy_dirs))
# Store results for plotting
results = {}

for strategy_dir in strategy_dirs:
    strategy_name = strategy_dir.name
    results[strategy_name] = {'noise_levels': [], 'intended_cc_rates': [], 'actual_cc_rates': []}
    
    for noise_level in noise_levels:
        intended_cc_counts = []
        actual_cc_counts = []
        
        # Get all repetition directories
        repetition_dirs = [d for d in strategy_dir.iterdir() if d.is_dir() and d.name.startswith('repetition_')]
        
        for rep_dir in repetition_dirs:
            csv_file = rep_dir / f"{noise_level}.csv"
            
            if csv_file.exists():
                # Read the CSV file
                df = pd.read_csv(csv_file)
                
                # Get intended actions for both players
                intended_actions_p1 = df.iloc[0]['Intended Actions']
                intended_actions_p2 = df.iloc[1]['Intended Actions']
                
                # Count intended cooperation (CC) - both players cooperate
                intended_cc_count = sum(1 for a1, a2 in zip(intended_actions_p1, intended_actions_p2) 
                                      if a1 == 'C' and a2 == 'C')
                
                # Get actual CC count from the CSV
                actual_cc_count = df.iloc[0]['CC count']  # Same for both rows
                
                intended_cc_counts.append(intended_cc_count / 1000)  # Convert to rate
                actual_cc_counts.append(actual_cc_count / 1000)  # Convert to rate
        
        if intended_cc_counts:  # If we have data for this noise level
            results[strategy_name]['noise_levels'].append(noise_level)
            results[strategy_name]['intended_cc_rates'].append(np.mean(intended_cc_counts))
            results[strategy_name]['actual_cc_rates'].append(np.mean(actual_cc_counts))

# Sort data by noise levels for proper plotting
for strategy_name, data in results.items():
    if data['noise_levels']:
        # Sort all lists by noise levels
        sorted_indices = sorted(range(len(data['noise_levels'])), key=lambda i: data['noise_levels'][i])
        data['noise_levels'] = [data['noise_levels'][i] for i in sorted_indices]
        data['intended_cc_rates'] = [data['intended_cc_rates'][i] for i in sorted_indices]
        data['actual_cc_rates'] = [data['actual_cc_rates'][i] for i in sorted_indices]

# Create plots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Plot intended CC rates (before noise)
for strategy_name, data in results.items():
    if data['noise_levels']:  # Only plot if we have data
        ax1.plot(data['noise_levels'], data['intended_cc_rates'], 
                marker='o', label=strategy_name, linewidth=2, markersize=6)

ax1.set_xlabel('Noise Level')
ax1.set_ylabel('Intended CC Rate (Before Noise)')
ax1.set_title('Intended Mutual Cooperation Rates by Noise Level')
ax1.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
ax1.grid(True, alpha=0.3)
ax1.set_ylim(0, 1)
ax1.set_xlim(0, 0.5)
ax1.set_xticks(np.arange(0, 0.55, 0.05))

# Plot actual CC rates (after noise)
for strategy_name, data in results.items():
    if data['noise_levels']:  # Only plot if we have data
        ax2.plot(data['noise_levels'], data['actual_cc_rates'], 
                marker='s', label=strategy_name, linewidth=2, markersize=6)

ax2.set_xlabel('Noise Level')
ax2.set_ylabel('Actual CC Rate (After Noise)')
ax2.set_title('Actual Mutual Cooperation Rates by Noise Level')
ax2.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
ax2.grid(True, alpha=0.3)
ax2.set_ylim(0, 1)
ax2.set_xlim(0, 0.5)
ax2.set_xticks(np.arange(0, 0.55, 0.05))

plt.tight_layout()
plt.show()

# Print summary statistics
print("\\nSummary Statistics:")
print("=" * 50)
for strategy_name, data in results.items():
    if data['noise_levels']:
        intended_mean = np.mean(data['intended_cc_rates'])
        actual_mean = np.mean(data['actual_cc_rates'])
        noise_impact = intended_mean - actual_mean
        print(f"{strategy_name:20s}: Intended={intended_mean:.3f}, Actual={actual_mean:.3f}, Impact={noise_impact:.3f}")

# %%
# Average Score Analysis
score_results = {}

for strategy_dir in strategy_dirs:
    strategy_name = strategy_dir.name
    score_results[strategy_name] = {'noise_levels': [], 'avg_scores': [], 'score_stds': []}
    
    for noise_level in noise_levels:
        scores = []
        
        # Get all repetition directories
        repetition_dirs = [d for d in strategy_dir.iterdir() if d.is_dir() and d.name.startswith('repetition_')]
        
        for rep_dir in repetition_dirs:
            csv_file = rep_dir / f"{noise_level}.csv"
            
            if csv_file.exists():
                # Read the CSV file
                df = pd.read_csv(csv_file)
                
                # Get scores for both players and average them (since it's self-play)
                score_p1 = df.iloc[0]['Score']
                score_p2 = df.iloc[1]['Score']
                avg_score = (score_p1 + score_p2) / 2
                
                scores.append(avg_score)
        
        if scores:  # If we have data for this noise level
            score_results[strategy_name]['noise_levels'].append(noise_level)
            score_results[strategy_name]['avg_scores'].append(np.mean(scores))
            score_results[strategy_name]['score_stds'].append(np.std(scores))

# Sort score data by noise levels for proper plotting
for strategy_name, data in score_results.items():
    if data['noise_levels']:
        # Sort all lists by noise levels
        sorted_indices = sorted(range(len(data['noise_levels'])), key=lambda i: data['noise_levels'][i])
        data['noise_levels'] = [data['noise_levels'][i] for i in sorted_indices]
        data['avg_scores'] = [data['avg_scores'][i] for i in sorted_indices]
        data['score_stds'] = [data['score_stds'][i] for i in sorted_indices]

# Create score plot
plt.figure(figsize=(12, 8))

for strategy_name, data in score_results.items():
    if data['noise_levels']:  # Only plot if we have data
        plt.errorbar(data['noise_levels'], data['avg_scores'], 
                    yerr=data['score_stds'], 
                    marker='o', label=strategy_name, linewidth=2, 
                    markersize=6, capsize=5, capthick=2)

plt.xlabel('Noise Level')
plt.ylabel('Average Score')
plt.title('Average Score vs Noise Level (Self-Play)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, alpha=0.3)
plt.xlim(0, 0.5)
plt.xticks(np.arange(0, 0.55, 0.05))

plt.tight_layout()
plt.show()

# Print detailed score summary statistics
print("\nScore Summary Statistics - Percentage Change from No Noise:")
print("=" * 120)

# Create header
header = f"{'Strategy':<20}"
for noise in noise_levels:
    if noise == 0:
        header += f"{'No Noise':<12}"
    else:
        header += f"{f'{noise} (%)' :<12}"
print(header)
print("-" * 120)

for strategy_name, data in score_results.items():
    if data['noise_levels'] and len(data['avg_scores']) >= 1:
        # Find the no-noise baseline score
        no_noise_score = None
        no_noise_idx = None
        
        for i, noise_level in enumerate(data['noise_levels']):
            if noise_level == 0:
                no_noise_score = data['avg_scores'][i]
                no_noise_idx = i
                break
        
        if no_noise_score is not None and no_noise_score > 0:
            row = f"{strategy_name:<20}"
            
            # For each noise level, show score and percentage change
            for target_noise in noise_levels:
                if target_noise in data['noise_levels']:
                    idx = data['noise_levels'].index(target_noise)
                    score = data['avg_scores'][idx]
                    
                    if target_noise == 0:
                        row += f"{score:<12.1f}"
                    else:
                        pct_change = ((score - no_noise_score) / no_noise_score) * 100
                        row += f"{pct_change:<12.1f}"
                else:
                    row += f"{'N/A':<12}"
            
            print(row)
        else:
            # If no baseline, just show raw scores
            row = f"{strategy_name:<20}"
            for target_noise in noise_levels:
                if target_noise in data['noise_levels']:
                    idx = data['noise_levels'].index(target_noise)
                    score = data['avg_scores'][idx]
                    row += f"{score:<12.1f}"
                else:
                    row += f"{'N/A':<12}"
            print(row)

print(f"\nNote: Percentages show change from no-noise baseline. Negative values indicate score decrease.")

# Additional analysis: Score vs CC rate correlation
print("\n\nScore vs Cooperation Rate Analysis:")
print("=" * 50)
print(f"{'Strategy':<20} {'Score-CC Correlation':<20}")
print("-" * 40)

for strategy_name in score_results.keys():
    if (strategy_name in results and strategy_name in score_results and 
        len(score_results[strategy_name]['avg_scores']) > 1):
        
        scores = score_results[strategy_name]['avg_scores']
        cc_rates = results[strategy_name]['actual_cc_rates']
        
        if len(scores) == len(cc_rates) and len(scores) > 1:
            correlation = np.corrcoef(scores, cc_rates)[0, 1]
            print(f"{strategy_name:<20} {correlation:<20.3f}")
