# %%
import axelrod as axl

players = [axl.CautiousQLearner(), axl.Defector(), axl.ZDExtort2()]
axl.Tournament(players, turns=100, repetitions=1).play().summarise()
# Out:
# ...
# Analysing: 100%|██████████| 25/25 [00:00<00:00, 330.38it/s]
# [Player(Rank=0, Name='ZD-Extort-2: 0.1111111111111111, 0.5', Median_score=np.float64(2.21), Cooperation_rating=0.325, Wins=np.float64(1.0), Initial_C_rate=np.float64(1.0), Original_index=2, CC_rate=0.285, CD_rate=0.04, DC_rate=0.17, DD_rate=0.505, CC_to_C_rate=np.float64(0.8571428571428571), CD_to_C_rate=np.float64(0.2857142857142857), DC_to_C_rate=np.float64(0.38235294117647056), DD_to_C_rate=0),
#  Player(Rank=1, Name='Defector', Median_score=np.float64(1.48), Cooperation_rating=0.0, Wins=np.float64(2.0), Initial_C_rate=np.float64(0.0), Original_index=1, CC_rate=0.0, CD_rate=0.0, DC_rate=0.12000000000000001, DD_rate=0.88, CC_to_C_rate=0, CD_to_C_rate=0, DC_to_C_rate=0, DD_to_C_rate=0),
# ...

# %%
axl.Match((axl.CautiousQLearner(), axl.Defector()), turns=100).play()
# Out:
# [(C, D),
#  (C, D),
#  (C, D),
#  (C, D),
#  (C, D),
#  (C, D),
#  (D, D),
#  (C, D),
#  (C, D),
#  (C, D),
#  (C, D),
#  (D, D),
#  (C, D),
#  (C, D),
#  (C, D),
#  (C, D),
#  (C, D),
#  (C, D),
#  (C, D),
#  (C, D),
#  (C, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (C, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (C, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (C, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (C, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (C, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (C, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (C, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (C, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
#  (D, D),
# ...
