# %%
from pymdp.envs import GridWorldEnv
from pymdp.jax.task import PyMDPEnv
from pymdp.jax.agent import Agent as AIFAgent

# %%
import jax.numpy as jnp
import jax.tree_util as jtu
from jax import nn, vmap, lax, jit
from jax import random as jr
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
NUM_STATES = 2
NUM_OBS = 3
NUM_ACTIONS = 2

# %%
COOP = 0
DEFECT = 1

# %%
A = jnp.array([
    jnp.eye(2,2),
    jnp.eye(2,2),
])
A = jnp.broadcast_to(A, (1,2,2,2))
A.shape
# Out:
# (1, 2, 2, 2)

# %%
B = np.ones((1,2,2,2,2))

B[0, 0, COOP, :, COOP] = 1
B[0, 0, COOP, :, DEFECT] = 0
B[0, 0, DEFECT, :, COOP] = 0
B[0, 0, DEFECT, :, DEFECT] = 1

B[0, 1, :, :, :] = 0.5

B = jnp.array([
    np.ones((2,2,2)) * 0.5,
    np.ones((2,2,2)) * 0.5,
])
B = jnp.broadcast_to(B, (1,2,2,2,2))
B.shape
# Out:
# (1, 2, 2, 2, 2)

# %%
C = jnp.broadcast_to(jnp.array([(0,0), (1, 0)]), (1, 2, 2))
C.shape
# Out:
# (1, 2, 2)

# %%
D = [jnp.ones((1, 2, 2)) * 0.5]
D[0].shape
# Out:
# (1, 2, 2)

# %%
pB = [jnp.ones_like(B[0]) / NUM_STATES]
pB[0].shape
# Out:
# (2, 2, 2)

# %%
A.shape[2:]
# Out:
# (2, 2)

# %%
agent = AIFAgent(
    [A], 
    [B], 
    [C],
    [D], 
    pB=None, 
    E=None, 
    pA=None,  
    learn_A=False, 
    learn_B=True, 
    learn_D=False, 
    use_utility=True, 
    policy_len=1,
)
agent
# Out:
# (2,)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 agent = AIFAgent(
#       2     [A],
#       3     [B],
#       4     [C],
#       5     [D],
#       6     pB=None,
#       7     E=None,
#       8     pA=None,
#       9     learn_A=False,
#      10     learn_B=True,
#      11     learn_D=False,
#      12     use_utility=True,
#      13     policy_len=1,
#      14 )
#      15 agent
#
#     [... skipping hidden 2 frame]
#
# File ~/code/AIFNIPD/.venv/lib/python3.13/site-packages/pymdp/jax/agent.py:158, in Agent.__init__(self, A, B, C, D, E, pA, pB, A_dependencies, B_dependencies, qs, q_pi, H, I, policy_len, control_fac_idx, policies, gamma, alpha, inductive_depth, inductive_threshold, inductive_epsilon, use_utility, use_states_info_gain, use_param_info_gain, use_inductive, onehot_obs, action_selection, sampling_mode, inference_algo, num_iter, learn_A, learn_B, learn_C, learn_D, learn_E)
#     156 factor_dims = tuple([self.num_states[f] for f in self.A_dependencies[m]])
#     157 print(factor_dims)
# --> 158 assert self.A[m].shape[2:] == factor_dims, f"Please input an `A_dependencies` whose {m}-th indices correspond to the hidden state factors that line up with lagging dimensions of A[{m}]..."
#     159 if self.pA != None:
#     160     assert self.pA[m].shape[2:] == factor_dims if self.pA[m] is not None else True, f"Please input an `A_dependencies` whose {m}-th indices correspond to the hidden state factors that line up with lagging dimensions of pA[{m}]..."
#
# AssertionError: Please input an `A_dependencies` whose 0-th indices correspond to the hidden state factors that line up with lagging dimensions of A[0]...

# %%
print(agent.A[0].shape)
# Out:
# (2, 2, 2)

# %%
obs = [jnp.broadcast_to(jnp.array([0, 0]), (2,2))]
obs[0].shape
# Out:
# (2, 2)

# %%
prior = [jnp.zeros((2,2,2))]
prior[0].shape
# Out:
# (2, 2, 2)

# %%
qs = agent.infer_states(obs, prior)
qs[0].shape
# Out:
# (2, 1, 2, 2)

# %%
# qs = [jnp.broadcast_to(jnp.array([[0.5, 0.5]]), (1,1, NUM_STATES))]
# qs

# %%
qpi, nefe = agent.infer_policies(qs)
qpi
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 qpi, nefe = agent.infer_policies(qs)
#       2 qpi
#
#     [... skipping hidden 1 frame]
#
# File ~/code/AIFNIPD/.venv/lib/python3.13/site-packages/pymdp/jax/agent.py:411, in Agent.infer_policies(self, qs)
#     399 latest_belief = jtu.tree_map(lambda x: x[:, -1], qs) # only get the posterior belief held at the current timepoint
#     400 infer_policies = partial(
#     401     control.update_posterior_policies_inductive,
#     402     self.policies,
#    (...)    408     use_inductive=self.use_inductive
#     409 )
# --> 411 q_pi, G = vmap(infer_policies)(
#     412     latest_belief,
#     413     self.A,
#     414     self.B,
#     415     self.C,
#     416     self.E,
#     417     self.pA,
#     418     self.pB,
#     419     I = self.I,
#     420     gamma=self.gamma,
#     421     inductive_epsilon=self.inductive_epsilon
#     422 )
#     424 return q_pi, G
#
#     [... skipping hidden 7 frame]
#
# File ~/code/AIFNIPD/.venv/lib/python3.13/site-packages/pymdp/jax/control.py:366, in update_posterior_policies_inductive(policy_matrix, qs_init, A, B, C, E, pA, pB, A_dependencies, B_dependencies, I, gamma, inductive_epsilon, use_utility, use_states_info_gain, use_param_info_gain, use_inductive)
#     358 compute_G_fixed_states = partial(compute_G_policy_inductive, qs_init, A, B, C, pA, pB, A_dependencies, B_dependencies, I, inductive_epsilon=inductive_epsilon,
#     359                                  use_utility=use_utility,  use_states_info_gain=use_states_info_gain, use_param_info_gain=use_param_info_gain, use_inductive=use_inductive)
#     361 # only in the case of policy-dependent qs_inits
#     362 # in_axes_list = (1,) * n_factors
#     363 # all_efe_of_policies = vmap(compute_G_policy, in_axes=(in_axes_list, 0))(qs_init_pi, policy_matrix)
#     364
#     365 # policies needs to be an NDarray of shape (n_policies, n_timepoints, n_control_factors)
# --> 366 neg_efe_all_policies = vmap(compute_G_fixed_states)(policy_matrix)
#     368 return nn.softmax(gamma * neg_efe_all_policies + log_stable(E)), neg_efe_all_policies
#
#     [... skipping hidden 7 frame]
#
# File ~/code/AIFNIPD/.venv/lib/python3.13/site-packages/pymdp/jax/control.py:350, in compute_G_policy_inductive(qs_init, A, B, C, pA, pB, A_dependencies, B_dependencies, I, policy_i, inductive_epsilon, use_utility, use_states_info_gain, use_param_info_gain, use_inductive)
#     348 qs = qs_init
#     349 neg_G = 0.
# --> 350 final_state, _ = lax.scan(scan_body, (qs, neg_G), jnp.arange(policy_i.shape[0]))
#     351 _, neg_G = final_state
#     352 return neg_G
#
#     [... skipping hidden 10 frame]
#
# File ~/code/AIFNIPD/.venv/lib/python3.13/site-packages/pymdp/jax/control.py:328, in compute_G_policy_inductive.<locals>.scan_body(carry, t)
#     324 def scan_body(carry, t):
#     326     qs, neg_G = carry
# --> 328     qs_next = compute_expected_state(qs, B, policy_i[t], B_dependencies)
#     330     qo = compute_expected_obs(qs_next, A, A_dependencies)
#     332     info_gain = compute_info_gain(qs_next, qo, A, A_dependencies) if use_states_info_gain else 0.
#
# File ~/code/AIFNIPD/.venv/lib/python3.13/site-packages/pymdp/jax/control.py:169, in compute_expected_state(qs_prior, B, u_t, B_dependencies)
#     167 for B_f, u_f, deps in zip(B, u_t, B_dependencies):
#     168     relevant_factors = [qs_prior[idx] for idx in deps]
# --> 169     qs_next_f = factor_dot(B_f[...,u_f], relevant_factors, keep_dims=(0,))
#     170     qs_next.append(qs_next_f)
#     172 # P(s'|s, u) = \sum_{s, u} P(s'|s) P(s|u) P(u|pi)P(pi) because u </-> pi
#
#     [... skipping hidden 15 frame]
#
# File ~/code/AIFNIPD/.venv/lib/python3.13/site-packages/pymdp/jax/maths.py:39, in factor_dot(M, xs, keep_dims)
#      37 keep_dims = () if keep_dims is None else keep_dims
#      38 dims = tuple((i,) for i in range(M.ndim) if i not in keep_dims)
# ---> 39 return factor_dot_flex(M, xs, dims, keep_dims=keep_dims)
#
#     [... skipping hidden 15 frame]
#
# File ~/code/AIFNIPD/.venv/lib/python3.13/site-packages/pymdp/jax/maths.py:62, in factor_dot_flex(M, xs, dims, keep_dims)
#      59     args.extend(row)
#      61 args += [keep_dims]
# ---> 62 return contract(*args, backend='jax')
#
# File ~/code/AIFNIPD/.venv/lib/python3.13/site-packages/opt_einsum/contract.py:595, in contract(subscripts, out, use_blas, optimize, memory_limit, backend, *operands, **kwargs)
#     593 # Build the contraction list and operand
#     594 contraction_list: ContractionListType
# --> 595 operands, contraction_list = contract_path(  # type: ignore
#     596     *operands_list, optimize=optimize, memory_limit=memory_limit, einsum_call=True, use_blas=use_blas
#     597 )
#     599 # check if performing contraction or just building expression
#     600 if gen_expression:
#
# File ~/code/AIFNIPD/.venv/lib/python3.13/site-packages/opt_einsum/contract.py:312, in contract_path(subscripts, use_blas, optimize, memory_limit, shapes, *operands, **kwargs)
#     309 sh = input_shapes[tnum]
#     311 if len(sh) != len(term):
# --> 312     raise ValueError(
#     313         f"Einstein sum subscript '{input_list[tnum]}' does not contain the "
#     314         f"correct number of indices for operand {tnum}."
#     315     )
#     316 for cnum, char in enumerate(term):
#     317     dim = int(sh[cnum])
#
# ValueError: Einstein sum subscript 'b' does not contain the correct number of indices for operand 1.

# %%
agent.sample_action(qpi)
# Out:
# Array([[1]], dtype=int32)

# %%
print(agent.qs)
# Out:
# None

# %%
def action_pair_to_obs(own, other):
    return own * 2 + other

action_pair_to_obs(0,0)
# Out:
# 0

# %%
def rollout(rng_key, agent, num_timesteps):
    batch_size = agent.batch_size

    def step_fn(carry, x):
        rng_key = carry["rng_key"]
        ts = carry["ts"]

        def true_fn(carry):
            # Initialization logic for the first timestep (ts == 0)
            uncertain_qs = [jnp.ones((1, 1, NUM_STATES)) / NUM_STATES]
            qpi, _ = agent.infer_policies(uncertain_qs)
            action = agent.sample_action(qpi)
            empirical_prior, qs = agent.update_empirical_prior(action, uncertain_qs)
            
            # Use a dummy previous action for the very first observation
            obs_val = action_pair_to_obs(action[0][0], 1)
            observation = [jnp.broadcast_to(obs_val, (1, 1))]
            
            return uncertain_qs, action, observation, empirical_prior

        def false_fn(carry):
            # Logic for subsequent timesteps
            observation = carry["observation"]
            previous_action = carry["action"]
            empirical_prior = carry["empirical_prior"]
            
            qs = agent.infer_states(observation, empirical_prior)
            qpi, nefe = agent.infer_policies(qs)
            action = agent.sample_action(qpi)
            
            obs_val = action_pair_to_obs(action[0][0], previous_action[0][0])
            new_observation = [jnp.broadcast_to(obs_val, (1, 1))]
            
            new_empirical_prior, _ = agent.update_empirical_prior(action, qs)
            
            return qs, action, new_observation, new_empirical_prior

        qs, action, observation, empirical_prior = lax.cond(ts == 0, true_fn, false_fn, carry)

        history_slice = {
            "qs": qs[0],
            "action": action[0],
            "observation": observation[0],
        }

        carry = {
            "rng_key": rng_key,
            "action": action,
            "observation": observation,
            "empirical_prior": empirical_prior,
            "ts": ts + 1,
        }
        return carry, history_slice

    initial_carry = {
        "rng_key": jr.split(rng_key, 1)[0],
        "action": jnp.zeros((1, 1), dtype=jnp.int32),
        "observation": [jnp.zeros((1, 1), dtype=jnp.int32)],
        "empirical_prior": [jnp.zeros((1, NUM_STATES), dtype=jnp.float32)],
        "ts": 0
    }

    last, history = lax.scan(step_fn, initial_carry, None, length=num_timesteps + 1)
    return last, history

# %%
key = jr.PRNGKey(0)

jitted_func = jit(rollout, static_argnums=[2,])

# %%
x = jitted_func(key, agent, 50)

# %%
x[1]
# Out:
# {'action': Array([[1],
#         [0],
#         [1],
#         [1],
#         [0],
#         [1],
#         [1],
#         [0],
#         [1],
#         [1],
#         [0],
#         [1],
#         [1],
#         [0],
#         [1],
#         [1],
#         [0],
#         [1],
#         [1],
#         [0],
#         [1],
#         [1],
#         [0],
#         [1],
#         [1],
#         [0],
#         [1],
#         [1],
#         [0],
#         [1],
#         [1],
#         [0],
#         [1],
#         [1],
#         [0],
#         [1],
#         [1],
#         [0],
#         [1],
#         [1],
#         [0],
#         [1],
#         [1],
#         [0],
#         [1],
#         [1],
#         [0],
#         [1],
#         [1],
#         [0],
#         [1]], dtype=int32),
#  'observation': Array([[[3]],
#
#         [[1]],
#
#         [[2]],
#
#         [[3]],
#
#         [[1]],
#
#         [[2]],
#
#         [[3]],
#
#         [[1]],
#
#         [[2]],
#
#         [[3]],
#
#         [[1]],
#
#         [[2]],
#
#         [[3]],
#
#         [[1]],
#
#         [[2]],
#
#         [[3]],
#
#         [[1]],
#
#         [[2]],
#
#         [[3]],
#
#         [[1]],
#
#         [[2]],
#
#         [[3]],
#
#         [[1]],
#
#         [[2]],
#
#         [[3]],
#
#         [[1]],
#
#         [[2]],
#
#         [[3]],
#
#         [[1]],
#
#         [[2]],
#
#         [[3]],
#
#         [[1]],
#
#         [[2]],
#
#         [[3]],
#
#         [[1]],
#
#         [[2]],
#
#         [[3]],
#
#         [[1]],
#
#         [[2]],
#
#         [[3]],
#
#         [[1]],
#
#         [[2]],
#
#         [[3]],
#
#         [[1]],
#
#         [[2]],
#
#         [[3]],
#
#         [[1]],
#
#         [[2]],
#
#         [[3]],
#
#         [[1]],
#
#         [[2]]], dtype=int32),
#  'qs': Array([[[[2.5000000e-01, 2.5000000e-01, 2.5000000e-01, 2.5000000e-01]]],
#
#
#         [[[3.1948981e-17, 8.5892522e-17, 2.9942864e-16, 1.0000000e+00]]],
#
#
#         [[[7.4262569e-19, 1.0000000e+00, 7.4262569e-19, 2.4506696e-17]]],
#
#
#         [[[3.4565122e-17, 1.1186125e-19, 1.0000000e+00, 1.4541957e-18]]],
#
#
#         [[[1.7080391e-17, 1.7080391e-17, 1.7080391e-17, 1.0000000e+00]]],
#
#
#         [[[7.4262569e-19, 1.0000000e+00, 7.4262569e-19, 2.4506696e-17]]],
#
#
#         [[[3.4565122e-17, 1.1186125e-19, 1.0000000e+00, 1.4541957e-18]]],
#
#
#         [[[1.7080391e-17, 1.7080391e-17, 1.7080391e-17, 1.0000000e+00]]],
#
#
#         [[[7.4262569e-19, 1.0000000e+00, 7.4262569e-19, 2.4506696e-17]]],
#
#
#         [[[3.4565122e-17, 1.1186125e-19, 1.0000000e+00, 1.4541957e-18]]],
#
#
#         [[[1.7080391e-17, 1.7080391e-17, 1.7080391e-17, 1.0000000e+00]]],
#
#
#         [[[7.4262569e-19, 1.0000000e+00, 7.4262569e-19, 2.4506696e-17]]],
#
#
#         [[[3.4565122e-17, 1.1186125e-19, 1.0000000e+00, 1.4541957e-18]]],
#
#
#         [[[1.7080391e-17, 1.7080391e-17, 1.7080391e-17, 1.0000000e+00]]],
#
#
#         [[[7.4262569e-19, 1.0000000e+00, 7.4262569e-19, 2.4506696e-17]]],
#
#
#         [[[3.4565122e-17, 1.1186125e-19, 1.0000000e+00, 1.4541957e-18]]],
#
#
#         [[[1.7080391e-17, 1.7080391e-17, 1.7080391e-17, 1.0000000e+00]]],
#
#
#         [[[7.4262569e-19, 1.0000000e+00, 7.4262569e-19, 2.4506696e-17]]],
#
#
#         [[[3.4565122e-17, 1.1186125e-19, 1.0000000e+00, 1.4541957e-18]]],
#
#
#         [[[1.7080391e-17, 1.7080391e-17, 1.7080391e-17, 1.0000000e+00]]],
#
#
#         [[[7.4262569e-19, 1.0000000e+00, 7.4262569e-19, 2.4506696e-17]]],
#
#
#         [[[3.4565122e-17, 1.1186125e-19, 1.0000000e+00, 1.4541957e-18]]],
#
#
#         [[[1.7080391e-17, 1.7080391e-17, 1.7080391e-17, 1.0000000e+00]]],
#
#
#         [[[7.4262569e-19, 1.0000000e+00, 7.4262569e-19, 2.4506696e-17]]],
#
#
#         [[[3.4565122e-17, 1.1186125e-19, 1.0000000e+00, 1.4541957e-18]]],
#
#
#         [[[1.7080391e-17, 1.7080391e-17, 1.7080391e-17, 1.0000000e+00]]],
#
#
#         [[[7.4262569e-19, 1.0000000e+00, 7.4262569e-19, 2.4506696e-17]]],
#
#
#         [[[3.4565122e-17, 1.1186125e-19, 1.0000000e+00, 1.4541957e-18]]],
#
#
#         [[[1.7080391e-17, 1.7080391e-17, 1.7080391e-17, 1.0000000e+00]]],
#
#
#         [[[7.4262569e-19, 1.0000000e+00, 7.4262569e-19, 2.4506696e-17]]],
#
#
#         [[[3.4565122e-17, 1.1186125e-19, 1.0000000e+00, 1.4541957e-18]]],
#
#
#         [[[1.7080391e-17, 1.7080391e-17, 1.7080391e-17, 1.0000000e+00]]],
#
#
#         [[[7.4262569e-19, 1.0000000e+00, 7.4262569e-19, 2.4506696e-17]]],
#
#
#         [[[3.4565122e-17, 1.1186125e-19, 1.0000000e+00, 1.4541957e-18]]],
#
#
#         [[[1.7080391e-17, 1.7080391e-17, 1.7080391e-17, 1.0000000e+00]]],
#
#
#         [[[7.4262569e-19, 1.0000000e+00, 7.4262569e-19, 2.4506696e-17]]],
#
#
#         [[[3.4565122e-17, 1.1186125e-19, 1.0000000e+00, 1.4541957e-18]]],
#
#
#         [[[1.7080391e-17, 1.7080391e-17, 1.7080391e-17, 1.0000000e+00]]],
#
#
#         [[[7.4262569e-19, 1.0000000e+00, 7.4262569e-19, 2.4506696e-17]]],
#
#
#         [[[3.4565122e-17, 1.1186125e-19, 1.0000000e+00, 1.4541957e-18]]],
#
#
#         [[[1.7080391e-17, 1.7080391e-17, 1.7080391e-17, 1.0000000e+00]]],
#
#
#         [[[7.4262569e-19, 1.0000000e+00, 7.4262569e-19, 2.4506696e-17]]],
#
#
#         [[[3.4565122e-17, 1.1186125e-19, 1.0000000e+00, 1.4541957e-18]]],
#
#
#         [[[1.7080391e-17, 1.7080391e-17, 1.7080391e-17, 1.0000000e+00]]],
#
#
#         [[[7.4262569e-19, 1.0000000e+00, 7.4262569e-19, 2.4506696e-17]]],
#
#
#         [[[3.4565122e-17, 1.1186125e-19, 1.0000000e+00, 1.4541957e-18]]],
#
#
#         [[[1.7080391e-17, 1.7080391e-17, 1.7080391e-17, 1.0000000e+00]]],
#
#
#         [[[7.4262569e-19, 1.0000000e+00, 7.4262569e-19, 2.4506696e-17]]],
#
#
#         [[[3.4565122e-17, 1.1186125e-19, 1.0000000e+00, 1.4541957e-18]]],
#
#
#         [[[1.7080391e-17, 1.7080391e-17, 1.7080391e-17, 1.0000000e+00]]],
#
#
#         [[[7.4262569e-19, 1.0000000e+00, 7.4262569e-19, 2.4506696e-17]]]],      dtype=float32)}

# %%
actions = x[1]["action"]
actions = actions[1:]
actions = jnp.broadcast_to(actions, (1, 50, 1))
actions.shape, actions
# Out:
# ((1, 50, 1),
#  Array([[[0],
#          [1],
#          [1],
#          [0],
#          [1],
#          [1],
#          [0],
#          [1],
#          [1],
#          [0],
#          [1],
#          [1],
#          [0],
#          [1],
#          [1],
#          [0],
#          [1],
#          [1],
#          [0],
#          [1],
#          [1],
#          [0],
#          [1],
#          [1],
#          [0],
#          [1],
#          [1],
#          [0],
#          [1],
#          [1],
#          [0],
#          [1],
#          [1],
#          [0],
#          [1],
#          [1],
#          [0],
#          [1],
#          [1],
#          [0],
#          [1],
#          [1],
#          [0],
#          [1],
#          [1],
#          [0],
#          [1],
#          [1],
#          [0],
#          [1]]], dtype=int32))

# %%
observations = x[1]["observation"]
observations.shape
# Out:
# (51, 1, 1)

# %%
obs = []
for observation in observations:
    obs.append(observation[0, 0])
obs = jnp.array([obs])
obs.shape
# Out:
# (1, 51)

# %%
qs = x[1]["qs"]
qs_list = []
for q in qs:
    q = q.squeeze(0)
    q = q.squeeze(0)
    qs_list.append(q)

qs = jnp.array(qs_list)
qs = jnp.broadcast_to(qs, (1, 51, NUM_STATES))
qs.shape
# Out:
# (1, 51, 4)

# %%
[qs][0].shape[1], actions.shape[1] + 1
# Out:
# (51, 51)

# %%
agent_new = agent.infer_parameters([qs], obs, actions)

# %%
agent = agent_new

# %%
agent_new.B
# Out:
# [Array([[[[8.2127661e-01, 3.2894737e-03],
#           [1.0638298e-01, 1.3026981e-01],
#           [4.2034467e-04, 6.2500000e-02],
#           [2.9850747e-03, 2.2007042e-04]],
#
#          [[2.9787235e-02, 3.2894737e-03],
#           [1.4893617e-01, 4.2158517e-04],
#           [2.9424129e-03, 6.2500000e-02],
#           [8.9253730e-01, 4.7909331e-01]],
#
#          [[4.2553190e-03, 9.5065790e-01],
#           [2.1276595e-02, 8.6382800e-01],
#           [4.2034467e-04, 6.2500000e-02],
#           [2.9850747e-03, 2.2007042e-04]],
#
#          [[1.4468086e-01, 4.2763159e-02],
#           [7.2340423e-01, 5.4806070e-03],
#           [9.9621689e-01, 8.1250000e-01],
#           [1.0149254e-01, 5.2046657e-01]]]], dtype=float32)]

# %%
print(f"P(CC| CC, C) = {agent_new.B[0][0, 0, 0, 0]}")
print(f"P(CC| CC, D) = {agent_new.B[0][0, 0, 0, 1]}")
print(f"P(CC| CD, C) = {agent_new.B[0][0, 0, 1, 0]}")
print(f"P(CC| CD, D) = {agent_new.B[0][0, 0, 1, 1]}")
print(f"P(CC| DC, C) = {agent_new.B[0][0, 0, 2, 0]}")
print(f"P(CC| DC, D) = {agent_new.B[0][0, 0, 2, 1]}")
print(f"P(CC| DD, C) = {agent_new.B[0][0, 0, 3, 0]}")
print(f"P(CC| DD, D) = {agent_new.B[0][0, 0, 3, 1]}")

print(f"P(CD| CC, C) = {agent_new.B[0][0, 1, 0, 0]}")
print(f"P(CD| CC, D) = {agent_new.B[0][0, 1, 0, 1]}")
print(f"P(CD| CD, C) = {agent_new.B[0][0, 1, 1, 0]}")
print(f"P(CD| CD, D) = {agent_new.B[0][0, 1, 1, 1]}")
print(f"P(CD| DC, C) = {agent_new.B[0][0, 1, 2, 0]}")
print(f"P(CD| DC, D) = {agent_new.B[0][0, 1, 2, 1]}")
print(f"P(CD| DD, C) = {agent_new.B[0][0, 1, 3, 0]}")
print(f"P(CD| DD, D) = {agent_new.B[0][0, 1, 3, 1]}")

print(f"P(DC| CC, C) = {agent_new.B[0][0, 2, 0, 0]}")
print(f"P(DC| CC, D) = {agent_new.B[0][0, 2, 0, 1]}")
print(f"P(DC| CD, C) = {agent_new.B[0][0, 2, 1, 0]}")
print(f"P(DC| CD, D) = {agent_new.B[0][0, 2, 1, 1]}")
print(f"P(DC| DC, C) = {agent_new.B[0][0, 2, 2, 0]}")
print(f"P(DC| DC, D) = {agent_new.B[0][0, 2, 2, 1]}")
print(f"P(DC| DD, C) = {agent_new.B[0][0, 2, 3, 0]}")
print(f"P(DC| DD, D) = {agent_new.B[0][0, 2, 3, 1]}")

print(f"P(DD| CC, C) = {agent_new.B[0][0, 3, 0, 0]}")
print(f"P(DD| CC, D) = {agent_new.B[0][0, 3, 0, 1]}")
print(f"P(DD| CD, C) = {agent_new.B[0][0, 3, 1, 0]}")
print(f"P(DD| CD, D) = {agent_new.B[0][0, 3, 1, 1]}")
print(f"P(DD| DC, C) = {agent_new.B[0][0, 3, 2, 0]}")
print(f"P(DD| DC, D) = {agent_new.B[0][0, 3, 2, 1]}")
print(f"P(DD| DD, C) = {agent_new.B[0][0, 3, 3, 0]}")
print(f"P(DD| DD, D) = {agent_new.B[0][0, 3, 3, 1]}")
# Out:
# P(CC| CC, C) = 0.8212766051292419
# P(CC| CC, D) = 0.003289473708719015
# P(CC| CD, C) = 0.10638298094272614
# P(CC| CD, D) = 0.13026981055736542
# P(CC| DC, C) = 0.0004203446733299643
# P(CC| DC, D) = 0.0625
# P(CC| DD, C) = 0.0029850746504962444
# P(CC| DD, D) = 0.00022007041843608022
# P(CD| CC, C) = 0.029787234961986542
# P(CD| CC, D) = 0.003289473708719015
# P(CD| CD, C) = 0.1489361673593521
# P(CD| CD, D) = 0.00042158516589552164
# P(CD| DC, C) = 0.0029424128588289022
# P(CD| DC, D) = 0.0625
# P(CD| DD, C) = 0.8925372958183289
# P(CD| DD, D) = 0.4790933132171631
# P(DC| CC, C) = 0.0042553190141916275
# P(DC| CC, D) = 0.9506579041481018
# P(DC| CD, C) = 0.021276595070958138
# P(DC| CD, D) = 0.8638280034065247
# P(DC| DC, C) = 0.0004203446733299643
# P(DC| DC, D) = 0.0625
# P(DC| DD, C) = 0.0029850746504962444
# P(DC| DD, D) = 0.00022007041843608022
# P(DD| CC, C) = 0.14468085765838623
# P(DD| CC, D) = 0.042763158679008484
# P(DD| CD, C) = 0.7234042286872864
# P(DD| CD, D) = 0.0054806070402264595
# P(DD| DC, C) = 0.996216893196106
# P(DD| DC, D) = 0.8125
# P(DD| DD, C) = 0.10149253904819489
# P(DD| DD, D) = 0.5204665660858154
