# %%
import sys
from pathlib import Path
import pandas as pd
from experiments import result_utils

# Configuration
dir_agent_map = {
    "bqlearning": "Jax Bayesian QLearner",
    "qlearning": "Jax QLearner",
    "actinf": "JAX_AIF",
    "dbs": "DBS"
}

results_dir = Path("../../results/hyperparameters")

# Analyze all agents across all noise levels
print("Analyzing hyperparameter results...")
results_by_noise = result_utils.analyze_best_agents_per_noise(results_dir, dir_agent_map)

# Get top 10 agents for each noise level
top_agents = result_utils.get_top_n_agents(results_by_noise, n=100)

# Format for display
formatted_results = result_utils.format_results_for_display(top_agents, decimals=2)

print(f"Analysis complete! Found {len(formatted_results)} noise levels.")
# Out:
# Analyzing hyperparameter results...
# Analysis complete! Found 3 noise levels.

# %%
# Display results as 6 separate tables (one for each noise level)
for noise_level in sorted(formatted_results.keys()):
    print(f"\n{'='*100}")
    print(f"NOISE LEVEL: {noise_level}")
    print(f"{'='*100}\n")
    
    df = formatted_results[noise_level]
    # Add rank column
    df_display = df.copy()
    df_display.insert(0, 'Rank', range(1, len(df_display) + 1))
    
    display(df_display)
# Out:
# ====================================================================================================
# NOISE LEVEL: 0.0
# ====================================================================================================
#     Rank    Agent Type               Hyperparameters  Mean Score  \
# 0      1  Jax QLearner  QLearner_0.9_0.9_0.1_1_0.999     2747.10
# 1      2  Jax QLearner  QLearner_0.9_0.5_0.1_2_0.999     2694.13
# 2      3  Jax QLearner  QLearner_0.5_0.5_0.1_1_0.999     2662.23
# 3      4  Jax QLearner  QLearner_0.5_0.5_0.1_2_0.999     2598.90
# 4      5  Jax QLearner  QLearner_0.9_0.5_0.1_1_0.999     2588.92
# ..   ...           ...                           ...         ...
# 95    96  Jax QLearner    QLearner_0.9_0.9_0_4_0.999     1834.89
# 96    97  Jax QLearner    QLearner_0.1_0.9_0_3_0.999     1833.64
# 97    98  Jax QLearner    QLearner_0.1_0.1_0_5_0.999     1832.59
# 98    99  Jax QLearner    QLearner_0.5_0.9_0_3_0.999     1829.59
# 99   100  Jax QLearner    QLearner_0.1_0.5_0_4_0.999     1824.69
#
#     Num Repetitions
# 0                 5
# 1                 5
# 2                 5
# 3                 5
# 4                 5
# ..              ...
# 95                5
# 96                5
# 97                5
# 98                5
# 99                5
#
# [100 rows x 5 columns]
# ====================================================================================================
# NOISE LEVEL: 0.05
# ====================================================================================================
#     Rank    Agent Type               Hyperparameters  Mean Score  \
# 0      1  Jax QLearner  QLearner_0.9_0.9_0.1_1_0.999     2522.26
# 1      2  Jax QLearner  QLearner_0.5_0.5_0.1_1_0.999     2482.80
# 2      3  Jax QLearner  QLearner_0.5_0.9_0.1_1_0.999     2466.93
# 3      4  Jax QLearner  QLearner_0.5_0.5_0.1_2_0.999     2448.82
# 4      5  Jax QLearner   QLearner_0.5_0.5_0.1_1_0.99     2427.40
# ..   ...           ...                           ...         ...
# 95    96  Jax QLearner    QLearner_0.9_0.9_0_5_0.999     1848.28
# 96    97  Jax QLearner    QLearner_0.5_0.9_0_4_0.999     1841.57
# 97    98  Jax QLearner    QLearner_0.1_0.5_0_4_0.999     1836.00
# 98    99  Jax QLearner    QLearner_0.1_0.1_0_5_0.999     1831.79
# 99   100  Jax QLearner    QLearner_0.5_0.9_0_5_0.999     1823.04
#
#     Num Repetitions
# 0                 5
# 1                 5
# 2                 5
# 3                 5
# 4                 5
# ..              ...
# 95                5
# 96                5
# 97                5
# 98                5
# 99                5
#
# [100 rows x 5 columns]
# ====================================================================================================
# NOISE LEVEL: 0.1
# ====================================================================================================
#     Rank    Agent Type               Hyperparameters  Mean Score  \
# 0      1  Jax QLearner  QLearner_0.9_0.9_0.1_1_0.999     2405.98
# 1      2  Jax QLearner   QLearner_0.9_0.9_0.1_1_0.99     2393.65
# 2      3  Jax QLearner  QLearner_0.5_0.9_0.1_1_0.999     2348.86
# 3      4  Jax QLearner   QLearner_0.5_0.5_0.1_1_0.99     2347.53
# 4      5  Jax QLearner  QLearner_0.5_0.5_0.1_1_0.999     2346.97
# ..   ...           ...                           ...         ...
# 95    96  Jax QLearner    QLearner_0.9_0.9_0_5_0.999     1841.83
# 96    97  Jax QLearner    QLearner_0.1_0.5_0_3_0.999     1839.54
# 97    98  Jax QLearner    QLearner_0.5_0.9_0_5_0.999     1833.98
# 98    99  Jax QLearner    QLearner_0.1_0.1_0_5_0.999     1830.67
# 99   100  Jax QLearner    QLearner_0.1_0.5_0_4_0.999     1828.02
#
#     Num Repetitions
# 0                 5
# 1                 5
# 2                 5
# 3                 5
# 4                 5
# ..              ...
# 95                5
# 96                5
# 97                5
# 98                5
# 99                5
#
# [100 rows x 5 columns]

# %%
# Calculate average scores across all noise levels for each agent
print(f"\n{'='*100}")
print("AVERAGE SCORES ACROSS ALL NOISE LEVELS")
print(f"{'='*100}\n")

# Combine all results across noise levels
all_results = []
for noise_level, df in formatted_results.items():
    df_copy = df.copy()
    df_copy['noise_level'] = noise_level
    all_results.append(df_copy)

combined_df = pd.concat(all_results, ignore_index=True)

# Calculate average score for each agent across all noise levels
avg_scores = combined_df.groupby('Hyperparameters')['Mean Score'].mean().sort_values(ascending=False)
avg_scores_df = pd.DataFrame({
    'Hyperparameters': avg_scores.index,
    'Mean Score': avg_scores.values
})

# Add rank column
avg_scores_df.insert(0, 'Rank', range(1, len(avg_scores_df) + 1))

# Reset index for clean display
avg_scores_df = avg_scores_df.reset_index(drop=True)
# avg_scores_df.to_csv('avg_scores_df.csv', index=False)
display(avg_scores_df)
# Out:
# ====================================================================================================
# AVERAGE SCORES ACROSS ALL NOISE LEVELS
# ====================================================================================================
#      Rank               Hyperparameters   Mean Score
# 0       1  QLearner_0.9_0.9_0.1_1_0.999  2558.446667
# 1       2  QLearner_0.5_0.5_0.1_1_0.999  2497.333333
# 2       3  QLearner_0.5_0.9_0.1_1_0.999  2456.036667
# 3       4  QLearner_0.5_0.5_0.1_2_0.999  2450.203333
# 4       5   QLearner_0.9_0.9_0.1_1_0.99  2423.566667
# ..    ...                           ...          ...
# 98     99    QLearner_0.5_0.9_0_4_0.999  1843.390000
# 99    100    QLearner_0.1_0.9_0_3_0.999  1833.640000
# 100   101    QLearner_0.1_0.1_0_5_0.999  1831.683333
# 101   102    QLearner_0.1_0.5_0_4_0.999  1829.570000
# 102   103    QLearner_0.5_0.9_0_5_0.999  1828.510000
#
# [103 rows x 3 columns]
